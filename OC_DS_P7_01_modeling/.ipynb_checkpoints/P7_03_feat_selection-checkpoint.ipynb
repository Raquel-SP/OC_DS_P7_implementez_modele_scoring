# %% [markdown]
# # <font size="+3"><span style='color:#2994ff'> **P7 - Implémentez un modèle de scoring** </span></font>

# %% [markdown]
# <a id='LOADING_LIBRARIES'></a>
#
# ---
#
# ---
#
# <font size="+1"> **LOADING THE LIBRARIES** </font>
#
# ---

# %%
# ----------------
# Packages Update
# ----------------

# General libraries
import sys
import os
import glob
import pandas as pd
import numpy as np
import csv
import time
from datetime import datetime
import pickle
import gc

from xgboost import XGBRegressor

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance

import lightgbm as lgb
from lightgbm import LGBMClassifier
from lightgbm import LGBMRegressor

from sklearn.ensemble import RandomForestClassifier

import shap

import tools_dataframe
import tools_preprocessing
import tools_feat_engineering


# Data visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns


# Validation code PEP8
# %load_ext pycodestyle_magic
# %pycodestyle_on

# Warnings
import warnings
from warnings import simplefilter
warnings.filterwarnings(action='once')
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=ValueError)
simplefilter(action='ignore', category=UserWarning)

# Versions
print('Version of used libraries :')

print('Python                : ' + sys.version)
print('NumPy                 : ' + np.version.full_version)
print('Pandas                : ' + pd.__version__)
print('Dataframe tools      : ' + tools_dataframe.__version__)
now = datetime.now().isoformat()
print('\nLaunched on : ' + now)
# Out:
# 51:1: E402 module level import not at top of file
# 52:1: E402 module level import not at top of file
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic
# Version of used libraries :
# Python                : 3.11.3 (main, Apr 19 2023, 23:54:32) [GCC 11.2.0]
# NumPy                 : 1.24.3
# Pandas                : 1.5.3
# Dataframe tools      : 0.0.0
#
# Launched on : 2023-08-06T09:37:09.185754

# %% [markdown]
# <a id='USED_PARAMETERS'></a>
#
#
# <br>
#
#
# ---
# ---
#
# <font size="+1"> **PARAMETERS USED IN THIS NOTEBOOK** </font>
#
# ---

# %%
# Parameters used in this notebook

seed = 84

# %%
dico_pd_option = {
    'display.max_rows': 400,
    'display.max_column': 200,
    'display.width': 300,
    'display.precision': 4,
    'display.max_colwidth': 1000,
    'mode.chained_assignment': None}

for key, value in dico_pd_option.items():
    pd.set_option(key, value)

# %%
# Define the folder containing the files with the project data
P7_source = "/home/raquelsp/Documents/Openclassrooms/P7_implementez_modele_scoring/P7_travail/p7_source"

os.chdir(P7_source)
# Out:
# 2:80: E501 line too long (104 > 79 characters)

# %% [markdown]
# <font size="+3"><span style='color:#2994ff'> **P7 - Implémentez un modèle de scoring** </span></font>

# %% [markdown]
# <center><img src="./img/logo_projet.png" style="height: 250px;"/></center>
#
# **Prêt à dépenser** wants to implement a **credit scoring tool to calculate the probability of a customer repaying their loan**, and then **classify the application as either granted or refused credit**. It therefore wants to develop a classification algorithm based on a variety of data sources (behavioural data, data from other financial institutions, etc.).

# %% [markdown]
# This notebook includes the **feature selection**.
# Consists of finding a subset of relevant variables in a high-dimensional space. The loss of information caused by removing all the other variables must therefore be minimised.<br>
# The aim is to identify the optimum number of variables. I.e., the one that considers the most important variables for the different families of algorithms and results in reasonable calculation times, without affecting the performance of the models.

# %% [markdown]
# ## <font color = '#0085dd'>**Table of content**</font>
#
#
# [LOADING THE LIBRARIES](#LOADING_LIBRARIES)<br>
#
# [Parameters used in this notebook](#USED_PARAMETERS)<br>
#
# ---
#
#
# [**Loading datasets**](#datasets_loading)
#  * [Looking for empty features](#empty_feat)
#  * [Scaling data](#scaling_data)<br>
# <br>
#
# [**Feature selection**](#feature_selection)
#  * [Feature Importance using LightGBM](#feat_imp_LGBM)
#  * [Feature Importance using Random Forest](#feat_imp_RandomForest)<br>
#  * [Bilan Feature Selection](#bilan_feat_select_LGB)
#    * [Features with a combined normalized importance under 0.2 will be removed](#select_combined_normalized_importance_over_02)
#    * [Features with a combined normalized importance under 0.5 will be removed](#select_combined_normalized_importance_over_05)
#    * [15 highest values of combined normalized importance will be selected](#select_combined_normalized_importance_15highest)
#    * [10 best values of normalized importance from LightGBM and RandomForest will be selected](#select_combined_10best_lgbm_rf)
#    * [25 best values of normalized importance from LightGBM and RandomForest will be selected](#select_combined_25best_lgbm_rf)
#    * [Summary](#feat_select_summary)
# <br>
#
# ---

# %% [markdown]
# <a id='datasets_loading'></a>
#
# ---
# ---
#
# # <span style='background:#2994ff'><span style='color:white'>**Loading datasets** </span></span>

# %% [markdown]
# In this section, we will try to reduce the number of features, in such a way that it doesn't have a negative impact on the performance of the model.

# %%
# Load de datasets after feature engineering
path_train_dataset_after_feat_eng = \
    '../P7_scoring_credit/preprocessing/final_train_data.pkl'

with open(path_train_dataset_after_feat_eng, 'rb') as f:
    final_train_data = pickle.load(f)

# %%
# Load de datasets after feature engineering
path_test_dataset_after_feat_eng = \
    '../P7_scoring_credit/preprocessing/final_test_data.pkl'

with open(path_test_dataset_after_feat_eng, 'rb') as f:
    final_test_data = pickle.load(f)

# %%
# extracting the SK_ID_CURR from training and test data
skid_train = final_train_data['SK_ID_CURR']
skid_test = final_test_data['SK_ID_CURR']

# extracting the class labels for training data
target_train = final_train_data['TARGET']

# %%
# Create a copy of dataframes
train_data = final_train_data.copy()
test_data = final_test_data.copy()

# Dataframes alignement
train_data, test_data = train_data.align(test_data,
                                         join='inner', axis=1)
# Remove ID columns
train_data = train_data.drop(columns=['SK_ID_CURR'])
test_data = test_data.drop(columns=['SK_ID_CURR'])

print(f'train_data : {train_data.shape}')
print(f'test_data : {test_data.shape}')
# Out:
# train_data : (307511, 417)
# test_data : (48744, 417)

# %% [markdown]
# <a id='empty_feat'></a>
#
# ## <span style='background:#0085dd'><span style='color:white'>Looking for empty features</span></span>

# %%
print(f"Initial size of train_data {train_data.shape}")
print(f"\nInitial size of test_data {test_data.shape}")
# Out:
# Initial size of train_data (307511, 417)
#
# Initial size of test_data (48744, 417)

# %% [markdown]
# Here, empty features refer to those features which have just one unique value. These features are useless for the classifiers, as they do not contain any information.

# %%
empty_columns = []
for col in train_data.columns:
    if len(train_data[col].unique()) <= 1:
        empty_columns.append(col)

print(f"There are {len(empty_columns)} columns with just 1 unique value")
print("Removing these from dataset")
train_data = train_data.drop(empty_columns, axis=1)
test_data = test_data.drop(empty_columns, axis=1)
# Out:
# There are 22 columns with just 1 unique value
# Removing these from dataset

# %% [markdown]
# <a id='scaling_data'></a>
#
# ## <span style='background:#0085dd'><span style='color:white'>Scaling data</span></span>

# %%
# Extracting column names
train_columns = train_data.columns.tolist()
test_columns = test_data.columns.tolist()

# %%
# standardizing the data
scaler = StandardScaler()

train_data_std = scaler.fit_transform(train_data)
test_data_std = scaler.fit_transform(test_data)

# replacing nan values with 0
train_data_std[np.isnan(train_data_std)] = 0
test_data_std[np.isnan(test_data_std)] = 0

# %%
# Reconstruct datasets
train_data_std = pd.DataFrame(train_data_std, columns=train_columns)
test_data_std = pd.DataFrame(test_data_std, columns=test_columns)

# %% [markdown]
# <a id='feature_selection'></a>
#
# ---
# ---
#
# # <span style='background:#2994ff'><span style='color:white'>**Feature selection** </span></span>

# %% [markdown]
# <a id='feat_imp_LGBM'></a>
#
# ## <span style='background:#0085dd'><span style='color:white'>Feature Importance using LightGBM</span></span>

# %%
lGBM_train_data = train_data_std.copy()
lGBM_test_data = test_data_std.copy()

# %%
# Initialiser un tableau vide pour contenir les features importance
feature_importances_lGBM = np.zeros(lGBM_train_data.shape[1])

# Create the model with several hyperparameters
model_lGBM = lgb.LGBMClassifier(objective='binary',
                                boosting_type='goss',
                                n_estimators=10000,
                                class_weight='balanced',
                                verbose=-100)

# %%
# Split en jeux d'entraînement et de validation
train_features, valid_features, train_y, valid_y = \
    train_test_split(lGBM_train_data, target_train,
                     test_size=0.25, random_state=seed)

# Entraînement en utilisant early stopping
model_lGBM.fit(train_features, train_y)

# Sauvegarde des features importances
feature_importances_lGBM += model_lGBM.feature_importances_

# %%
# Create a dataframe for feature importance information
df_feat_importance_lGBM = \
    pd.DataFrame({'feature': list(lGBM_train_data.columns),
                  'lGBM_importance': feature_importances_lGBM})

# Normalize the feature importances
df_feat_importance_lGBM['lGBM_importance_normalized'] = \
    (df_feat_importance_lGBM['lGBM_importance']
     - df_feat_importance_lGBM['lGBM_importance'].min()) \
    / (df_feat_importance_lGBM['lGBM_importance'].max()
       - df_feat_importance_lGBM['lGBM_importance'].min())

df_feat_importance_lGBM = df_feat_importance_lGBM\
    .sort_values('lGBM_importance_normalized',
                 ascending=False).reset_index(drop=True)

# Create a column with the ranking position
df_feat_importance_lGBM["fi_lGBM_ranking"] = df_feat_importance_lGBM.index

df_feat_importance_lGBM.head(10)
# Out:
#                   feature  lGBM_importance  lGBM_importance_normalized  fi_lGBM_ranking
# 0       DAYS_REGISTRATION           4028.0                      1.0000                0
# 1            EXT_SOURCE_2           3927.0                      0.9749                1
# 2         DAYS_ID_PUBLISH           3891.0                      0.9660                2
# 3    CREDIT_ANNUITY_RATIO           3846.0                      0.9548                3
# 4              DAYS_BIRTH           3632.0                      0.9017                4
# 5         EXT_SOURCE_MEAN           3611.0                      0.8965                5
# 6     OBS_30_CREDIT_RATIO           3352.0                      0.8322                6
# 7     CREDIT_INCOME_RATIO           3280.0                      0.8143                7
# 8  DAYS_LAST_PHONE_CHANGE           3129.0                      0.7768                8
# 9        INCOME_EXT_RATIO           3088.0                      0.7666                9
# 8:49: E502 the backslash is redundant between brackets
# 10:57: E502 the backslash is redundant between brackets

# %%
# Find features with zero importance
zero_features = \
    list(df_feat_importance_lGBM[df_feat_importance_lGBM['lGBM_importance']
                                 == 0.0]['feature'])
print(f'{len(zero_features)} variables avec 0.0 importance :\n')
# Out:
# 38 variables avec 0.0 importance :

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_feat_importance_lGBM, x="lGBM_importance_normalized",
             bins=25, kde=True)
plt.title('Feature Importance from lightGBM')
plt.show()

# %% [markdown]
# <a id='feat_imp_RandomForest'></a>
#
# ## <span style='background:#0085dd'><span style='color:white'>Feature Importance using Random Forest</span></span>

# %%
RF_train_data = train_data.copy()
RF_test_data = test_data.copy()

# %%
# Initialiser un tableau vide pour contenir les features importance
feature_importances_RF = np.zeros(RF_train_data.shape[1])

# Create the model with several hyperparameters
randomForest = RandomForestClassifier(random_state=seed,
                                      class_weight='balanced')
# Out:
# 6:28: E128 continuation line under-indented for visual indent

# %%
# Split en jeux d'entraînement et de validation
train_features, valid_features, train_y, valid_y = \
    train_test_split(RF_train_data, target_train,
                     test_size=0.25, random_state=seed)

# Entraînement
randomForest.fit(train_features, train_y)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=84)

# %%
# Sauvegarde des features importances
feature_importances_RF += randomForest.feature_importances_

# %%
# Create a dataframe with feature importance information
df_feat_importance_RF = \
    pd.DataFrame({'feature': list(RF_train_data.columns),
                  'RF_importance': feature_importances_RF})

# Normalize feature importances
df_feat_importance_RF['RF_importance_normalized'] = \
    (df_feat_importance_RF['RF_importance']
     - df_feat_importance_RF['RF_importance'].min()) \
    / (df_feat_importance_RF['RF_importance'].max()
       - df_feat_importance_RF['RF_importance'].min())

df_feat_importance_RF = df_feat_importance_RF\
    .sort_values('RF_importance_normalized',
                 ascending=False).reset_index(drop=True)

# Create a column with the ranking position
df_feat_importance_RF["fi_RF_ranking"] = df_feat_importance_RF.index

df_feat_importance_RF.head(10)
# Out:
#                                      feature  RF_importance  RF_importance_normalized  fi_RF_ranking
# 0                            EXT_SOURCE_MEAN         0.0440                    1.0000              0
# 1                               EXT_SOURCE_2         0.0293                    0.6649              1
# 2                               EXT_SOURCE_3         0.0199                    0.4521              2
# 3                           INCOME_EXT_RATIO         0.0121                    0.2747              3
# 4                               EXT_SOURCE_1         0.0111                    0.2522              4
# 5                         CAR_EMPLOYED_RATIO         0.0105                    0.2398              5
# 6  CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL         0.0101                    0.2293              6
# 7                       CREDIT_ANNUITY_RATIO         0.0093                    0.2117              7
# 8                   DAYS_CREDIT_MEAN_OVERALL         0.0093                    0.2117              8
# 9                              DAYS_EMPLOYED         0.0093                    0.2111              9
# 8:45: E502 the backslash is redundant between brackets
# 10:53: E502 the backslash is redundant between brackets

# %%
# Exploration des variables avec zéro importance
# Find the features with zero importance
zero_features = \
    list(df_feat_importance_RF[df_feat_importance_RF['RF_importance']
                               == 0.0]['feature'])
print(f'{len(zero_features)} variables avec 0.0 importance :\n')
# zero_features
# Out:
# 10 variables avec 0.0 importance :

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_feat_importance_RF, x="RF_importance_normalized", bins=25)
plt.title('Feature Importance from Random Forest')
plt.show()
# Out:
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:13: E124 closing bracket does not match visual indentation

# %% [markdown]
# <a id='bilan_feat_select_LGB'></a>
#
# ## <span style='background:#0085dd'><span style='color:white'>Bilan Feature Selection</span></span>

# %%
df_feat_importances  = df_feat_importance_lGBM.merge(df_feat_importance_RF,
                                                     how='outer', on="feature")
df_feat_importances
# Out:
#                                                                               feature  lGBM_importance  lGBM_importance_normalized  fi_lGBM_ranking  RF_importance  RF_importance_normalized  fi_RF_ranking
# 0                                                                   DAYS_REGISTRATION           4028.0                      1.0000                0     7.5161e-03                1.7085e-01             19
# 1                                                                        EXT_SOURCE_2           3927.0                      0.9749                1     2.9251e-02                6.6491e-01              1
# 2                                                                     DAYS_ID_PUBLISH           3891.0                      0.9660                2     7.6548e-03                1.7400e-01             17
# 3                                                                CREDIT_ANNUITY_RATIO           3846.0                      0.9548                3     9.3139e-03                2.1172e-01              7
# 4                                                                          DAYS_BIRTH           3632.0                      0.9017                4     8.7083e-03                1.9795e-01             10
# 5                                                                     EXT_SOURCE_MEAN           3611.0                      0.8965                5     4.3992e-02                1.0000e+00              0
# 6                                                                 OBS_30_CREDIT_RATIO           3352.0                      0.8322                6     6.7986e-03                1.5454e-01             22
# 7                                                                 CREDIT_INCOME_RATIO           3280.0                      0.8143                7     7.6383e-03                1.7363e-01             18
# 8                                                              DAYS_LAST_PHONE_CHANGE           3129.0                      0.7768                8     7.8181e-03                1.7772e-01             15
# 9                                                                    INCOME_EXT_RATIO           3088.0                      0.7666                9     1.2087e-02                2.7474e-01              3
# 10                                                         REGION_POPULATION_RELATIVE           3017.0                      0.7490               10     6.0561e-03                1.3766e-01             36
# 11                                                           DAYS_CREDIT_MEAN_OVERALL           2947.0                      0.7316               11     9.3130e-03                2.1170e-01              8
# 12                                                         DAYS_PAYMENT_DIFF_MAX_MEAN           2907.0                      0.7217               12     5.9078e-03                1.3429e-01             44
# 13                                                HOUR_APPR_PROCESS_START_MEAN_LAST_5           2864.0                      0.7110               13     6.0602e-03                1.3776e-01             34
# 14                                                        DAYS_PAYMENT_DIFF_MEAN_MEAN           2816.0                      0.6991               14     6.2535e-03                1.4215e-01             30
# 15                                                        REGIONS_RATING_INCOME_MUL_0           2805.0                      0.6964               15     7.8887e-03                1.7932e-01             14
# 16                                                                         AMT_CREDIT           2757.0                      0.6845               16     7.4755e-03                1.6993e-01             20
# 17                                                       SELLERPLACE_AREA_MEAN_LAST_5           2726.0                      0.6768               17     5.6837e-03                1.2920e-01             54
# 18                                                                 CAR_EMPLOYED_RATIO           2717.0                      0.6745               18     1.0549e-02                2.3979e-01              5
# 19                                               DAYS_CREDIT_MEAN_CREDITACTIVE_ACTIVE           2678.0                      0.6648               19     6.4315e-03                1.4620e-01             27
# 20                                                                       EXT_SOURCE_3           2646.0                      0.6569               20     1.9890e-02                4.5212e-01              2
# 21                                                                   ENQ_CREDIT_RATIO           2624.0                      0.6514               21     4.7066e-03                1.0699e-01             76
# 22                                                                      DAYS_EMPLOYED           2612.0                      0.6485               22     9.2851e-03                2.1106e-01              9
# 23                                          PREV_AMT_ANNUITY_MEAN_LAST_5_INCOME_RATIO           2595.0                      0.6442               23     5.9217e-03                1.3461e-01             42
# 24                                                        AMT_CREDIT_SUM_MEAN_OVERALL           2589.0                      0.6428               24     6.2441e-03                1.4194e-01             32
# 25                                  CURRENT_CREDIT_DEBT_DIFF_MEAN_CREDITACTIVE_ACTIVE           2584.0                      0.6415               25     8.2294e-03                1.8706e-01             11
# 26                                             AMT_CREDIT_SUM_SUM_CREDITACTIVE_CLOSED           2579.0                      0.6403               26     5.9979e-03                1.3634e-01             39
# 27                                                            AMT_INSTALMENT_SUM_MEAN           2556.0                      0.6346               27     6.0156e-03                1.3674e-01             37
# 28                                        DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS           2555.0                      0.6343               28     6.0567e-03                1.3768e-01             35
# 29                                                          DAYS_DECISION_MEAN_LAST_5           2544.0                      0.6316               29     6.6822e-03                1.5189e-01             23
# 30                                                         DAYS_PAYMENT_DIFF_MIN_MEAN           2536.0                      0.6296               30     7.8167e-03                1.7768e-01             16
# 31                                      APPLICATION_AMT_TO_DECISION_RATIO_MEAN_LAST_5           2519.0                      0.6254               31     5.5000e-03                1.2502e-01             57
# 32                                   CURRENT_CREDIT_DEBT_DIFF_MIN_CREDITACTIVE_CLOSED           2510.0                      0.6231               32     5.3634e-03                1.2192e-01             63
# 33                                                          INTEREST_RATE_MAX_FIRST_2           2495.0                      0.6194               33     6.6787e-03                1.5182e-01             24
# 34                                                           INTEREST_RATE_MAX_LAST_5           2471.0                      0.6135               34     6.4781e-03                1.4726e-01             26
# 35                                                                 CREDIT_GOODS_RATIO           2467.0                      0.6125               35     7.9393e-03                1.8047e-01             13
# 36                                                               CONTRACT_ACTIVE_MEAN           2466.0                      0.6122               36     4.9539e-03                1.1261e-01             69
# 37                                             WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5           2411.0                      0.5986               37     4.6956e-03                1.0674e-01             77
# 38                                   AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2           2410.0                      0.5983               38     5.9372e-03                1.3496e-01             41
# 39                                                         INTEREST_SHARE_MEAN_LAST_5           2398.0                      0.5953               39     7.1882e-03                1.6340e-01             21
# 40                                             AMT_CREDIT_SUM_SUM_CREDITACTIVE_ACTIVE           2395.0                      0.5946               40     5.3663e-03                1.2198e-01             62
# 41                                     APPLICATION_AMT_TO_DECISION_RATIO_MEAN_FIRST_2           2387.0                      0.5926               41     5.5328e-03                1.2577e-01             56
# 42                                                        DAYS_PAYMENT_RATIO_MIN_MEAN           2387.0                      0.5926               42     5.9203e-03                1.3458e-01             43
# 43                                          AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2           2371.0                      0.5886               43     5.8926e-03                1.3395e-01             45
# 44                                                        INTEREST_SHARE_MEAN_FIRST_2           2294.0                      0.5695               44     6.3679e-03                1.4475e-01             28
# 45                                                   AMT_CREDIT_SUM_DEBT_MEAN_OVERALL           2225.0                      0.5524               45     5.8387e-03                1.3272e-01             47
# 46                                                     EXP_AMT_PAYMENT_DIFF_LAST_MEAN           2177.0                      0.5405               46     5.8248e-03                1.3240e-01             48
# 47                                                          AMT_DECLINED_MEAN_FIRST_2           2147.0                      0.5330               47     5.8796e-03                1.3365e-01             46
# 48                                                           CNT_INSTALMENT_MEAN_MEAN           2129.0                      0.5286               48     5.7276e-03                1.3020e-01             51
# 49                                                           AMT_INSTALMENT_MEAN_MEAN           2118.0                      0.5258               49     6.0922e-03                1.3848e-01             33
# 50                                                           AMT_ANNUITY_MEAN_FIRST_2           2065.0                      0.5127               50     5.7955e-03                1.3174e-01             49
# 51                                                       DAYS_PAYMENT_RATIO_MEAN_MEAN           2052.0                      0.5094               51     5.9646e-03                1.3558e-01             40
# 52                                            EXP_DAYS_PAYMENT_RATIO_LAST_LAST_1_YEAR           2048.0                      0.5084               52     5.4939e-03                1.2488e-01             58
# 53                                    AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5           2040.0                      0.5065               53     5.7792e-03                1.3137e-01             50
# 54                                                                ANNUITY_MEAN_LAST_5           2019.0                      0.5012               54     5.6654e-03                1.2878e-01             55
# 55                                                     NUM_INSTALMENT_NUMBER_MAX_MEAN           2011.0                      0.4993               55     4.7684e-03                1.0839e-01             74
# 56                                           AMT_CREDIT_APPLICATION_RATIO_MEAN_LAST_5           1994.0                      0.4950               56     5.4104e-03                1.2298e-01             61
# 57                                                                       EXT_SOURCE_1           1965.0                      0.4878               57     1.1097e-02                2.5224e-01              4
# 58                                                    AMT_INSTALMENT_MEAN_LAST_1_YEAR           1960.0                      0.4866               58     4.9199e-03                1.1184e-01             70
# 59                                                               ANNUITY_MEAN_FIRST_2           1954.0                      0.4851               59     5.4259e-03                1.2334e-01             60
# 60                                                 DAYS_PAYMENT_DIFF_MEAN_LAST_1_YEAR           1953.0                      0.4849               60     4.7676e-03                1.0837e-01             75
# 61                                                    NAME_GOODS_CATEGORY_MEAN_LAST_5           1926.0                      0.4782               61     4.4689e-03                1.0158e-01             84
# 62                                                    PRODUCT_COMBINATION_MEAN_LAST_5           1897.0                      0.4710               62     4.4779e-03                1.0179e-01             81
# 63                                                            CNT_INSTALMENT_MEAN_SUM           1881.0                      0.4670               63     5.4658e-03                1.2424e-01             59
# 64                                                            AMT_ANNUITY_MEAN_LAST_5           1880.0                      0.4667               64     5.6838e-03                1.2920e-01             53
# 65                                                   NUM_INSTALMENT_VERSION_MEAN_MEAN           1855.0                      0.4605               65     4.2845e-03                9.7391e-02             87
# 66                                                   AMT_CREDIT_GOODS_DIFF_SUM_LAST_5           1845.0                      0.4580               66     5.7196e-03                1.3002e-01             52
# 67                                                           AMT_DECLINED_MEAN_LAST_5           1803.0                      0.4476               67     5.3565e-03                1.2176e-01             64
# 68                       AGE_EMPLOYED_DIFF_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1756.0                      0.4359               68     4.8591e-03                1.1045e-01             72
# 69                             EXT_SOURCE_2_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1753.0                      0.4352               69     3.9824e-03                9.0525e-02             98
# 70                                                      NUM_INSTALMENT_NUMBER_MAX_SUM           1751.0                      0.4347               70     5.0218e-03                1.1415e-01             68
# 71                      APARTMENTS_SUM_AVG_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1736.0                      0.4310               71     4.2257e-03                9.6056e-02             90
# 72                                                            HOUR_APPR_PROCESS_START           1729.0                      0.4292               72     4.2641e-03                9.6929e-02             88
# 73                    ANNUITY_INCOME_RATIO_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1697.0                      0.4213               73     3.9946e-03                9.0801e-02             97
# 74                                                        NAME_TYPE_SUITE_MEAN_LAST_5           1689.0                      0.4193               74     4.0225e-03                9.1437e-02             95
# 75                            EXT_SOURCE_2_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1656.0                      0.4111               75     5.0976e-03                1.1588e-01             67
# 76                                                                   AMT_INCOME_TOTAL           1656.0                      0.4111               76     4.8622e-03                1.1053e-01             71
# 77                                                DAYS_PAYMENT_RATIO_MEAN_LAST_1_YEAR           1615.0                      0.4009               77     5.1781e-03                1.1770e-01             66
# 78                                                  DAYS_PAYMENT_DIFF_MIN_LAST_1_YEAR           1576.0                      0.3913               78     6.2498e-03                1.4207e-01             31
# 79                                           CREDIT_TYPE_Consumer credit_MEAN_OVERALL           1563.0                      0.3880               79     3.4084e-03                7.7476e-02            113
# 80                                                 CNT_INSTALMENT_MEAN_COMPLETED_MEAN           1549.0                      0.3846               80     4.4731e-03                1.0168e-01             83
# 81                                                                     APARTMENTS_AVG           1516.0                      0.3764               81     4.3505e-03                9.8892e-02             85
# 82                              AMT_ANNUITY_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1513.0                      0.3756               82     3.7099e-03                8.4331e-02            102
# 83                                                  CREDIT_ACTIVE_Active_MEAN_OVERALL           1488.0                      0.3694               83     6.0114e-03                1.3665e-01             38
# 84                                                       AMT_DOWN_PAYMENT_MEAN_LAST_5           1445.0                      0.3587               84     4.5310e-03                1.0299e-01             79
# 85                                                           CHANNEL_TYPE_MEAN_LAST_5           1437.0                      0.3568               85     3.5836e-03                8.1461e-02            104
# 86                              AMT_ANNUITY_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1426.0                      0.3540               86     3.4106e-03                7.7527e-02            112
# 87                                                 CNT_INSTALMENT_MEAN_YEAR_REST_MEAN           1395.0                      0.3463               87     4.1685e-03                9.4756e-02             92
# 88                                                                       LANDAREA_AVG           1381.0                      0.3429               88     3.6794e-03                8.3638e-02            103
# 89                                               DAYS_FIRST_LAST_DUE_DIFF_MEAN_LAST_5           1359.0                      0.3374               89     4.2292e-03                9.6136e-02             89
# 90                                                      RATE_DOWN_PAYMENT_MEAN_LAST_5           1338.0                      0.3322               90     3.9089e-03                8.8854e-02            100
# 91                                                        YEARS_BEGINEXPLUATATION_AVG           1331.0                      0.3304               91     4.1617e-03                9.4600e-02             93
# 92                                       APPLICATION_AMT_TO_DECISION_RATIO_MIN_LAST_5           1316.0                      0.3267               92     3.5292e-03                8.0223e-02            106
# 93                                                                   BASEMENTAREA_AVG           1269.0                      0.3150               93     3.9650e-03                9.0130e-02             99
# 94                                                       WEEKDAY_APPR_PROCESS_START_0           1198.0                      0.2974               94     2.5578e-03                5.8142e-02            144
# 95                                                   NAME_SELLER_INDUSTRY_MEAN_LAST_5           1190.0                      0.2954               95     3.5357e-03                8.0371e-02            105
# 96                                               MISSING_VALUES_TOTAL_PREV_SUM_LAST_5           1171.0                      0.2907               96     4.0353e-03                9.1728e-02             94
# 97                                                                  NONLIVINGAREA_AVG           1121.0                      0.2783               97     3.0553e-03                6.9450e-02            122
# 98                                                  AMT_CREDIT_YIELD_GROUP_MIN_LAST_5           1117.0                      0.2773               98     3.0487e-03                6.9301e-02            123
# 99       EXT_SOURCE_MEAN_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE           1075.0                      0.2669               99     3.5192e-03                7.9996e-02            108
# 100                        AMT_INCOME_TOTAL_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE           1052.0                      0.2612              100     2.9938e-03                6.8052e-02            125
# 101                                                               ORGANIZATION_TYPE_0           1032.0                      0.2562              101     4.4736e-03                1.0169e-01             82
# 102   APARTMENTS_SUM_AVG_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE           1027.0                      0.2550              102     3.3746e-03                7.6708e-02            114
# 103      EXT_SOURCE_MEAN_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE           1025.0                      0.2545              103     3.8314e-03                8.7092e-02            101
# 104                                            EXP_AMT_PAYMENT_RATIO_LAST_LAST_1_YEAR           1001.0                      0.2485              104     4.2942e-03                9.7612e-02             86
# 105         EXT_SOURCE_2_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            998.0                      0.2478              105     3.4417e-03                7.8235e-02            110
# 106                                                    CODE_REJECT_REASON_MEAN_LAST_5            980.0                      0.2433              106     3.2787e-03                7.4529e-02            116
# 107                                                        AMT_PAYMENT_DIFF_MEAN_MEAN            972.0                      0.2413              107     4.2138e-03                9.5786e-02             91
# 108                                                           CNT_PAYMENT_SUM_FIRST_2            970.0                      0.2408              108     3.5079e-03                7.9740e-02            109
# 109   APARTMENTS_SUM_AVG_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            946.0                      0.2349              109     3.4369e-03                7.8125e-02            111
# 110                                                                       OWN_CAR_AGE            939.0                      0.2331              110     3.1026e-03                7.0527e-02            119
# 111                                               AMT_CREDIT_MAX_OVERDUE_MEAN_OVERALL            920.0                      0.2284              111     2.6072e-03                5.9265e-02            139
# 112                                                         AMT_PAYMENT_DIFF_MAX_MEAN            864.0                      0.2145              112     3.3406e-03                7.5937e-02            115
# 113                                                  MONTHS_BALANCE_MEAN_MEAN_OVERALL            857.0                      0.2128              113     2.6778e-03                6.0869e-02            136
# 114               AMT_ANNUITY_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            843.0                      0.2093              114     2.3472e-03                5.3355e-02            155
# 115                                                      NAME_CLIENT_TYPE_MEAN_LAST_5            841.0                      0.2088              115     2.5704e-03                5.8428e-02            143
# 116          AMT_ANNUITY_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            839.0                      0.2083              116     2.6802e-03                6.0924e-02            135
# 117          AMT_ANNUITY_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            825.0                      0.2048              117     4.5139e-03                1.0261e-01             80
# 118              AMT_ANNUITY_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            822.0                      0.2041              118     2.3182e-03                5.2695e-02            156
# 119                                                                   YEARS_BUILD_AVG            814.0                      0.2021              119     3.0791e-03                6.9992e-02            121
# 120    AGE_EMPLOYED_DIFF_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            799.0                      0.1984              120     2.5943e-03                5.8972e-02            140
# 121                                                         AMT_PAYMENT_DIFF_MEAN_MAX            796.0                      0.1976              121     3.1026e-03                7.0526e-02            120
# 122                                                NAME_CASH_LOAN_PURPOSE_MEAN_LAST_5            796.0                      0.1976              122     2.5866e-03                5.8797e-02            141
# 123        APARTMENTS_SUM_AVG_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            787.0                      0.1954              123     2.3111e-03                5.2534e-02            157
# 124                                     WEIGHTED_STATUS_MEAN_MEAN_CREDITACTIVE_CLOSED            787.0                      0.1954              124     2.6665e-03                6.0614e-02            137
# 125                                                 WEIGHTED_STATUS_MEAN_MEAN_OVERALL            783.0                      0.1944              125     2.9355e-03                6.6728e-02            126
# 126                                                     NAME_PAYMENT_TYPE_MEAN_LAST_5            777.0                      0.1929              126     2.2948e-03                5.2164e-02            160
# 127              EXT_SOURCE_1_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            774.0                      0.1922              127     3.5280e-03                8.0196e-02            107
# 128                                                          STATUS_MEAN_MEAN_OVERALL            771.0                      0.1914              128     2.7493e-03                6.2495e-02            130
# 129          EXT_SOURCE_1_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            760.0                      0.1887              129     2.6871e-03                6.1081e-02            133
# 130        AGE_EMPLOYED_DIFF_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            758.0                      0.1882              130     2.6840e-03                6.1011e-02            134
# 131          EXT_SOURCE_1_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            750.0                      0.1862              131     2.4665e-03                5.6067e-02            145
# 132                                                        AMT_PAYMENT_RATIO_MEAN_MIN            746.0                      0.1852              132     3.0017e-03                6.8234e-02            124
# 133                                         AMT_PAYMENT_DIFF_MAX_FIRST_5_INSTALLMENTS            738.0                      0.1832              133     2.1053e-03                4.7856e-02            167
# 134                                                 AMT_CREDIT_SUM_LIMIT_MEAN_OVERALL            734.0                      0.1822              134     2.0811e-03                4.7305e-02            171
# 135              EXT_SOURCE_1_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            728.0                      0.1807              135     2.8106e-03                6.3889e-02            128
# 136       APARTMENTS_SUM_AVG_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            723.0                      0.1795              136     2.3963e-03                5.4472e-02            153
# 137  ANNUITY_INCOME_RATIO_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            723.0                      0.1795              137     2.2537e-03                5.1231e-02            161
# 138      ANNUITY_INCOME_RATIO_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            694.0                      0.1723              138     2.2495e-03                5.1135e-02            162
# 139                                              STATUS_MEAN_MEAN_CREDITACTIVE_ACTIVE            691.0                      0.1715              139     2.2990e-03                5.2260e-02            158
# 140          EXT_SOURCE_2_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            686.0                      0.1703              140     2.7689e-03                6.2940e-02            129
# 141                                                              CONTRACT_SIGNED_MEAN            674.0                      0.1673              141     1.7004e-03                3.8653e-02            194
# 142                                                                     ENTRANCES_AVG            673.0                      0.1671              142     2.4544e-03                5.5793e-02            147
# 143    APARTMENTS_SUM_AVG_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            671.0                      0.1666              143     2.7108e-03                6.1619e-02            131
# 144                                                          AMT_ANNUITY_MEAN_OVERALL            666.0                      0.1653              144     2.0868e-03                4.7435e-02            169
# 145     ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            658.0                      0.1634              145     2.5726e-03                5.8480e-02            142
# 146                                                     NAME_PRODUCT_TYPE_MEAN_LAST_5            645.0                      0.1601              146     2.2400e-03                5.0919e-02            163
# 147     AMT_INCOME_TOTAL_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            642.0                      0.1594              147     2.4473e-03                5.5631e-02            149
# 148                                                           STATUS_MAX_MEAN_OVERALL            641.0                      0.1591              148     2.0841e-03                4.7375e-02            170
# 149                                                                   SK_DPD_MAX_MEAN            640.0                      0.1589              149     1.8487e-03                4.2024e-02            186
# 150      EXT_SOURCE_MEAN_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            630.0                      0.1564              150     4.5995e-03                1.0455e-01             78
# 151        ANNUITY_INCOME_RATIO_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            626.0                      0.1554              151     1.9913e-03                4.5266e-02            177
# 152                                              AMT_ANNUITY_MEAN_CREDITACTIVE_ACTIVE            621.0                      0.1542              152     1.8178e-03                4.1322e-02            189
# 153                                                       AMT_PAYMENT_RATIO_MEAN_MEAN            616.0                      0.1529              153     4.8096e-03                1.0933e-01             73
# 154                     EXT_SOURCE_1_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY            602.0                      0.1495              154     2.4334e-03                5.5314e-02            151
# 155           AMT_ANNUITY_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            595.0                      0.1477              155     2.3589e-03                5.3621e-02            154
# 156         EXT_SOURCE_2_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            593.0                      0.1472              156     1.6882e-03                3.8376e-02            195
# 157                EXT_SOURCE_1_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            589.0                      0.1462              157     2.0646e-03                4.6932e-02            173
# 158                                                 AMT_PAYMENT_RATIO_MIN_LAST_1_YEAR            587.0                      0.1457              158     2.6897e-03                6.1140e-02            132
# 159                AGE_EMPLOYED_DIFF_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY            586.0                      0.1455              159     3.1479e-03                7.1556e-02            118
# 160          EXT_SOURCE_MEAN_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            583.0                      0.1447              160     4.0080e-03                9.1106e-02             96
# 161               AMT_ANNUITY_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            583.0                      0.1447              161     2.0204e-03                4.5927e-02            175
# 162              EXT_SOURCE_2_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            576.0                      0.1430              162     2.4453e-03                5.5585e-02            150
# 163                                                          OBS_30_CNT_SOCIAL_CIRCLE            564.0                      0.1400              163     2.4539e-03                5.5780e-02            148
# 164          AMT_INCOME_TOTAL_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            549.0                      0.1363              164     1.9634e-03                4.4631e-02            181
# 165                                                      AMT_CREDIT_LIMIT_ACTUAL_MEAN            542.0                      0.1346              165     1.8614e-03                4.2312e-02            185
# 166                                                          CNT_DRAWINGS_CURRENT_SUM            537.0                      0.1333              166     1.9820e-03                4.5053e-02            179
# 167                                                        AMT_REQ_CREDIT_BUREAU_YEAR            530.0                      0.1316              167     2.1040e-03                4.7828e-02            168
# 168                                                               SK_DPD_DEF_MAX_MEAN            516.0                      0.1281              168     1.8451e-03                4.1941e-02            188
# 169                                                AMT_PAYMENT_RATIO_MEAN_LAST_1_YEAR            513.0                      0.1274              169     2.4643e-03                5.6016e-02            146
# 170           EXT_SOURCE_MEAN_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            502.0                      0.1246              170     2.4249e-03                5.5121e-02            152
# 171                                             MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2            492.0                      0.1221              171     2.6271e-03                5.9718e-02            138
# 172                                                     NAME_YIELD_GROUP_MEAN_FIRST_2            492.0                      0.1221              172     2.1836e-03                4.9637e-02            165
# 173                                                 AMT_PAYMENT_DIFF_MEAN_LAST_1_YEAR            478.0                      0.1187              173     2.9280e-03                6.6557e-02            127
# 174      AMT_INCOME_TOTAL_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            467.0                      0.1159              174     2.0551e-03                4.6715e-02            174
# 175                                                      AMT_DRAWINGS_ATM_CURRENT_SUM            466.0                      0.1157              175     1.6459e-03                3.7414e-02            198
# 176                                                         EXP_PAYMENT_MIN_DIFF_LAST            459.0                      0.1140              176     1.4722e-03                3.3464e-02            205
# 177                                                 STATUS_MAX_YEAR_REST_MEAN_OVERALL            456.0                      0.1132              177     2.0011e-03                4.5487e-02            176
# 178                                                      AMT_DRAWINGS_ATM_CURRENT_MAX            454.0                      0.1127              178     1.3694e-03                3.1128e-02            211
# 179                                                            MIN_PAYMENT_RATIO_MEAN            437.0                      0.1085              179     1.8654e-03                4.2404e-02            184
# 180                                                         MISSING_VALS_TOTAL_CC_SUM            433.0                      0.1075              180     1.9804e-03                4.5017e-02            180
# 181                                                                    OBS_DEF_30_MUL            432.0                      0.1072              181     1.4398e-03                3.2729e-02            207
# 182                                                               CNT_DRAWING_SUM_MAX            431.0                      0.1070              182     1.5205e-03                3.4564e-02            203
# 183                                                                 NAME_TYPE_SUITE_0            428.0                      0.1063              183     1.2159e-03                2.7640e-02            217
# 184              EXT_SOURCE_2_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            425.0                      0.1055              184     1.3788e-03                3.1341e-02            210
# 185                                                                   AMT_BALANCE_SUM            420.0                      0.1043              185     1.7899e-03                4.0687e-02            190
# 186                                    AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_ACTIVE            419.0                      0.1040              186     1.9195e-03                4.3633e-02            183
# 187                                                                     FLOORSMIN_AVG            415.0                      0.1030              187     1.6806e-03                3.8202e-02            196
# 188                     EXT_SOURCE_2_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY            412.0                      0.1023              188     2.0665e-03                4.6975e-02            172
# 189                                                     CNT_INSTALMENT_MEAN_REST_MEAN            405.0                      0.1005              189     1.5341e-03                3.4872e-02            202
# 190                                                                MONTHS_BALANCE_MAX            397.0                      0.0986              190     1.9578e-03                4.4504e-02            182
# 191                 AMT_ANNUITY_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            397.0                      0.0986              191     1.3232e-03                3.0079e-02            213
# 192                                                           AMT_PAYMENT_CURRENT_MAX            395.0                      0.0981              192     1.5955e-03                3.6269e-02            199
# 193          EXT_SOURCE_2_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            393.0                      0.0976              193     1.3372e-03                3.0397e-02            212
# 194              EXT_SOURCE_3_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            392.0                      0.0973              194     1.7212e-03                3.9125e-02            192
# 195            AMT_INCOME_TOTAL_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            382.0                      0.0948              195     1.7660e-03                4.0143e-02            191
# 196     AMT_INCOME_TOTAL_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            373.0                      0.0926              196     1.5944e-03                3.6243e-02            200
# 197                                                          EXP_AMT_DRAWING_SUM_LAST            372.0                      0.0924              197     1.9878e-03                4.5185e-02            178
# 198                EXT_SOURCE_2_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            364.0                      0.0904              198     2.2299e-03                5.0688e-02            164
# 199                                                                 OCCUPATION_TYPE_0            361.0                      0.0896              199     2.2961e-03                5.2193e-02            159
# 200                                                          AMT_PAYMENT_CURRENT_MEAN            352.0                      0.0874              200     1.5835e-03                3.5994e-02            201
# 201                      AMT_ANNUITY_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY            350.0                      0.0869              201     1.4623e-03                3.3240e-02            206
# 202                                                                      CNT_CHILDREN            338.0                      0.0839              202     1.1172e-03                2.5395e-02            221
# 203                     EXT_SOURCE_3_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY            335.0                      0.0832              203     1.7151e-03                3.8986e-02            193
# 204                                                          BALANCE_LIMIT_RATIO_MEAN            335.0                      0.0832              204     3.2496e-03                7.3868e-02            117
# 205                                                               NAME_HOUSING_TYPE_0            321.0                      0.0797              205     9.8835e-04                2.2467e-02            225
# 206          AMT_INCOME_TOTAL_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE            321.0                      0.0797              206     1.3867e-03                3.1521e-02            209
# 207                            EXT_SOURCE_3_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE            293.0                      0.0727              207     9.7591e-04                2.2184e-02            227
# 208                EXT_SOURCE_3_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            293.0                      0.0727              208     1.4317e-03                3.2545e-02            208
# 209                                                              WALLSMATERIAL_MODE_0            287.0                      0.0713              209     1.1839e-03                2.6912e-02            218
# 210                                                    DAYS_FIRST_DRAWING_MEAN_LAST_5            282.0                      0.0700              210     1.3109e-03                2.9799e-02            215
# 211            AMT_INCOME_TOTAL_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE            268.0                      0.0665              211     9.8144e-04                2.2310e-02            226
# 212                                                                   FLAG_WORK_PHONE            264.0                      0.0655              212     5.5585e-04                1.2635e-02            258
# 213                                                 NFLAG_INSURED_ON_APPROVAL_SUM_ALL            263.0                      0.0653              213     1.5008e-03                3.4114e-02            204
# 214                                                BALANCE_LIMIT_RATIO_MEAN_YEAR_REST            261.0                      0.0648              214     9.2581e-04                2.1045e-02            232
# 215                                                      PAYMENT_MIN_DIFF_MEAN_YEAR_1            254.0                      0.0631              215     7.7225e-04                1.7554e-02            240
# 216                                              NFLAG_INSURED_ON_APPROVAL_SUM_LAST_5            246.0                      0.0611              216     1.2468e-03                2.8341e-02            216
# 217                                                    NAME_PAYMENT_TYPE_MEAN_FIRST_2            246.0                      0.0611              217     9.9507e-04                2.2619e-02            224
# 218      AMT_INCOME_TOTAL_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE            239.0                      0.0593              218     1.3193e-03                2.9989e-02            214
# 219                                         CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL            232.0                      0.0576              219     1.0087e-02                2.2928e-01              6
# 220                                                            REG_CITY_NOT_WORK_CITY            222.0                      0.0551              220     6.6117e-04                1.5029e-02            251
# 221                                                   PAYMENT_MIN_DIFF_MEAN_YEAR_REST            218.0                      0.0541              221     9.4035e-04                2.1375e-02            228
# 222                                                              NAME_FAMILY_STATUS_0            215.0                      0.0534              222     1.1248e-03                2.5569e-02            220
# 223                                             NFLAG_INSURED_ON_APPROVAL_SUM_FIRST_2            213.0                      0.0529              223     8.4417e-04                1.9189e-02            237
# 224                                                   DAYS_FIRST_DRAWING_MEAN_FIRST_2            213.0                      0.0529              224     1.1838e-03                2.6909e-02            219
# 225                                                                 REGION_RATING_MAX            209.0                      0.0519              225     1.6465e-03                3.7428e-02            197
# 226                                                 CREDIT_TYPE_Car loan_MEAN_OVERALL            209.0                      0.0519              226     6.8004e-04                1.5458e-02            250
# 227                                                    PAYMENT_MIN_DIFF_MIN_YEAR_REST            204.0                      0.0506              227     8.0156e-04                1.8220e-02            238
# 228                                                       PAYMENT_MIN_DIFF_MIN_YEAR_1            198.0                      0.0492              228     6.2243e-04                1.4149e-02            254
# 229                                                         AMT_REQ_CREDIT_BUREAU_MON            197.0                      0.0489              229     7.4106e-04                1.6845e-02            244
# 230                                                      CNT_DRAWINGS_ATM_CURRENT_MAX            196.0                      0.0487              230     1.1157e-03                2.5362e-02            222
# 231                                                                        FLAG_PHONE            194.0                      0.0482              231     6.8457e-04                1.5561e-02            249
# 232                                                               SUM_FLAGS_DOCUMENTS            191.0                      0.0474              232     9.3484e-04                2.1250e-02            230
# 233                                               EXP_PAYMENT_MIN_DIFF_LAST_YEAR_REST            189.0                      0.0469              233     7.0521e-04                1.6030e-02            247
# ...
# 317                                           FLAG_LAST_APPL_PER_CONTRACT_MEAN_LAST_5             26.0                      0.0065              317     1.5013e-04                3.4128e-03            307
# 318                                                  FLAG_OVERDUE_RECENT_MEAN_OVERALL             25.0                      0.0062              318     1.7428e-04                3.9616e-03            296
# 319                            CREDIT_TYPE_Loan for business development_MEAN_OVERALL             23.0                      0.0057              319     8.3576e-05                1.8998e-03            318
# 320                                                                  FLAG_DOCUMENT_21             22.0                      0.0055              320     9.0985e-06                2.0682e-04            356
# 321                                                        REG_REGION_NOT_LIVE_REGION             22.0                      0.0055              321     1.6494e-04                3.7493e-03            302
# 322                                        CNT_CREDIT_PROLONG_MAX_CREDITACTIVE_CLOSED             22.0                      0.0055              322     1.0145e-04                2.3060e-03            314
# 323                                     CREDIT_TYPE_Another type of loan_MEAN_OVERALL             22.0                      0.0055              323     3.5575e-05                8.0866e-04            332
# 324                                                     BALANCE_LIMIT_RATIO_MEAN_REST             21.0                      0.0052              324     3.3214e-05                7.5501e-04            333
# 325                                                    CNT_DRAWINGS_OTHER_CURRENT_SUM             21.0                      0.0052              325     1.8727e-04                4.2568e-03            293
# 326                                                         SK_DPD_MAX_COMPLETED_MEAN             20.0                      0.0050              326     1.8326e-05                4.1657e-04            343
# 327                                                  AMT_INTEREST_RECEIVABLE_MIN_REST             20.0                      0.0050              327     3.6277e-05                8.2463e-04            331
# 328                                    AMT_CREDIT_SUM_OVERDUE_MAX_CREDITACTIVE_CLOSED             20.0                      0.0050              328     1.2845e-05                2.9199e-04            348
# 329                                                                  FLAG_DOCUMENT_14             19.0                      0.0047              329     2.1795e-05                4.9543e-04            339
# 330                                       WEIGHTED_STATUS_MEAN_MEANCREDIT_ACTIVE_REST             19.0                      0.0047              330     7.6705e-05                1.7436e-03            320
# 331                                    AMT_ANNUITY_CREDIT_RATIO_MINCREDIT_ACTIVE_REST             15.0                      0.0037              331     3.9638e-05                9.0102e-04            330
# 332                                     CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL             14.0                      0.0035              332     2.0644e-05                4.6928e-04            341
# 333                                                            CONTRACT_Sent proposal             14.0                      0.0035              333     9.2773e-06                2.1089e-04            354
# 334                                                                  HOUSETYPE_MODE_0             13.0                      0.0032              334     1.3008e-04                2.9569e-03            313
# 335                   CREDIT_TYPE_Loan for working capital replenishment_MEAN_OVERALL             12.0                      0.0030              335     1.8459e-05                4.1960e-04            342
# 336                                                AMT_ANNUITY_MEANCREDIT_ACTIVE_REST             12.0                      0.0030              336     4.3836e-05                9.9645e-04            328
# 337                                                              CONTRACT_DEMAND_MEAN             10.0                      0.0025              337     1.7024e-05                3.8698e-04            345
# 338                                         AMT_CREDIT_SUM_DEBT_SUMCREDIT_ACTIVE_REST             10.0                      0.0025              338     7.3962e-06                1.6813e-04            360
# 339                                                        AMT_REQ_CREDIT_BUREAU_HOUR              9.0                      0.0022              339     8.4334e-05                1.9170e-03            317
# 340                                                       SK_DPD_RATIO_MEAN_REST_MEAN              9.0                      0.0022              340     5.8840e-06                1.3375e-04            361
# 341                                                                  FLAG_DOCUMENT_11              9.0                      0.0022              341     4.7306e-05                1.0753e-03            326
# 342                                                                  FLAG_DOCUMENT_15              9.0                      0.0022              342     1.2013e-05                2.7307e-04            349
# 343                                                    PAYMENT_MIN_DIFF_MIN_COMPLETED              8.0                      0.0020              343     2.3484e-05                5.3383e-04            338
# 344                                               AMT_CREDIT_GOODS_RATIO_MEAN_FIRST_2              8.0                      0.0020              344     6.4792e-03                1.4728e-01             25
# 345                                                          CNT_DRAWING_SUM_SUM_REST              7.0                      0.0017              345     2.6483e-05                6.0198e-04            336
# 346                                               NFLAG_LAST_APPL_IN_DAY_MEAN_FIRST_2              7.0                      0.0017              346     2.1545e-05                4.8975e-04            340
# 347                                              RATE_INTEREST_PRIVILEGED_MEAN_LAST_5              6.0                      0.0015              347     1.3008e-04                2.9570e-03            312
# 348                                                                   FLAG_DOCUMENT_9              6.0                      0.0015              348     5.7514e-05                1.3074e-03            324
# 349                                                                  FLAG_DOCUMENT_19              5.0                      0.0012              349     1.4812e-05                3.3670e-04            347
# 350                                         CREDIT_DAY_OVERDUE_MEANCREDIT_ACTIVE_REST              4.0                      0.0010              350     1.1200e-06                2.5459e-05            370
# 351                                                        MIN_PAYMENT_RATIO_MIN_REST              4.0                      0.0010              351     1.7909e-05                4.0709e-04            344
# 352                                                  CURRENCY_currency 1_MEAN_OVERALL              2.0                      0.0005              352     4.6291e-05                1.0523e-03            327
# 353                                                BALANCE_LIMIT_RATIO_MEAN_COMPLETED              2.0                      0.0005              353     9.2098e-06                2.0935e-04            355
# 354                                   AMT_ANNUITY_CREDIT_RATIO_MEANCREDIT_ACTIVE_REST              1.0                      0.0002              354     4.0063e-05                9.1068e-04            329
# 355                                                                  FLAG_DOCUMENT_17              1.0                      0.0002              355     9.5188e-06                2.1637e-04            352
# 356                                                                   FLAG_DOCUMENT_7              1.0                      0.0002              356     8.4254e-07                1.9152e-05            372
# 357                                                     SK_DPD_DEF_MAX_COMPLETED_MEAN              0.0                      0.0000              357     0.0000e+00                0.0000e+00            388
# 358                                                                 CONTRACT_XNA_MEAN              0.0                      0.0000              358     0.0000e+00                0.0000e+00            394
# 359                                          CNT_CREDIT_PROLONG_MAXCREDIT_ACTIVE_REST              0.0                      0.0000              359     4.9104e-07                1.1162e-05            377
# 360                                                            CONTRACT_CANCELED_MEAN              0.0                      0.0000              360     5.0312e-07                1.1437e-05            375
# 361                                                      CONTRACT_AMORTIZED DEBT_MEAN              0.0                      0.0000              361     5.9541e-07                1.3534e-05            374
# 362                                        AMT_CREDIT_SUM_LIMIT_MAXCREDIT_ACTIVE_REST              0.0                      0.0000              362     2.5562e-06                5.8106e-05            368
# 363                     EXT_SOURCE_3_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY              0.0                      0.0000              363     0.0000e+00                0.0000e+00            389
# 364                                         CNT_INSTALMENT_FUTURE_MEAN_COMPLETED_MEAN              0.0                      0.0000              364     0.0000e+00                0.0000e+00            387
# 365                                      AMT_CREDIT_SUM_OVERDUE_MAXCREDIT_ACTIVE_REST              0.0                      0.0000              365     1.6400e-21                3.7280e-20            384
# 366                            MAX_AMT_OVERDUE_DURATION_RATIO_MAX_CREDITACTIVE_ACTIVE              0.0                      0.0000              366     7.0482e-07                1.6021e-05            373
# 367                                                                    FLAG_EMP_PHONE              0.0                      0.0000              367     1.3924e-04                3.1651e-03            311
# 368                                                                        FLAG_MOBIL              0.0                      0.0000              368     2.5378e-07                5.7688e-06            378
# 369                               CURRENT_DEBT_TO_CREDIT_RATIO_MEANCREDIT_ACTIVE_REST              0.0                      0.0000              369     9.4518e-06                2.1485e-04            353
# 370                                                                 CONTRACT_Approved              0.0                      0.0000              370     1.2467e-20                2.8340e-19            381
# 371                                                                  CONTRACT_Refused              0.0                      0.0000              371     8.9610e-08                2.0370e-06            380
# 372                              CNT_PROLONGED_MAX_OVERDUE_MUL_MEANCREDIT_ACTIVE_REST              0.0                      0.0000              372     1.9112e-06                4.3444e-05            369
# 373                                       DAYS_CREDIT_UPDATE_MEAN_CREDITACTIVE_ACTIVE              0.0                      0.0000              373     5.0591e-06                1.1500e-04            363
# 374                                           CREDIT_DURATION_MAX_CREDITACTIVE_ACTIVE              0.0                      0.0000              374     5.0118e-07                1.1392e-05            376
# 375                                         CREDIT_TYPE_Interbank credit_MEAN_OVERALL              0.0                      0.0000              375     0.0000e+00                0.0000e+00            391
# 376                                                   DAYS_CREDIT_UPDATE_MEAN_OVERALL              0.0                      0.0000              376     8.9747e-06                2.0401e-04            357
# 377                                                      CREDIT_DURATION_MEAN_OVERALL              0.0                      0.0000              377     1.0476e-05                2.3813e-04            351
# 378                                       MAX_AMT_OVERDUE_DURATION_RATIO_MEAN_OVERALL              0.0                      0.0000              378     0.0000e+00                0.0000e+00            390
# 379                                          FLAG_LAST_APPL_PER_CONTRACT_MEAN_FIRST_2              0.0                      0.0000              379     5.5382e-06                1.2589e-04            362
# 380                                                  CURRENCY_currency 4_MEAN_OVERALL              0.0                      0.0000              380     2.1888e-21                4.9755e-20            383
# 381                                               CREDIT_ACTIVE_Bad debt_MEAN_OVERALL              0.0                      0.0000              381     2.8635e-06                6.5091e-05            367
# 382                                                              SK_DPD_SUM_COMPLETED              0.0                      0.0000              382     0.0000e+00                0.0000e+00            386
# 383                                CREDIT_TYPE_Cash loan (non-earmarked)_MEAN_OVERALL              0.0                      0.0000              383     2.9569e-06                6.7214e-05            366
# 384                                                   MIN_PAYMENT_RATIO_MIN_COMPLETED              0.0                      0.0000              384     4.2943e-06                9.7615e-05            364
# 385                                                             SK_DPD_RATIO_MAX_REST              0.0                      0.0000              385     1.0536e-05                2.3950e-04            350
# 386             CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN_OVERALL              0.0                      0.0000              386     0.0000e+00                0.0000e+00            392
# 387                       CREDIT_TYPE_Loan for the purchase of equipment_MEAN_OVERALL              0.0                      0.0000              387     9.0643e-07                2.0604e-05            371
# 388                                             AMT_INTEREST_RECEIVABLE_MIN_COMPLETED              0.0                      0.0000              388     0.0000e+00                0.0000e+00            385
# 389                                     CREDIT_TYPE_Mobile operator loan_MEAN_OVERALL              0.0                      0.0000              389     0.0000e+00                0.0000e+00            393
# 390                                         CREDIT_TYPE_Real estate loan_MEAN_OVERALL              0.0                      0.0000              390     5.6787e-21                1.2908e-19            382
# 391                                       CREDIT_DAY_OVERDUE_MEAN_CREDITACTIVE_CLOSED              0.0                      0.0000              391     3.6169e-06                8.2217e-05            365
# 392                                           CREDIT_DURATION_MAX_CREDITACTIVE_CLOSED              0.0                      0.0000              392     8.4814e-06                1.9279e-04            359
# 393                                                  DAYS_CREDIT_ENDDATE_MEAN_OVERALL              0.0                      0.0000              393     8.7144e-06                1.9809e-04            358
# 394                                      DAYS_CREDIT_ENDDATE_MEAN_CREDITACTIVE_ACTIVE              0.0                      0.0000              394     1.8679e-07                4.2459e-06            379
# 1:20: E221 multiple spaces before operator

# %%
# Combine lGBM anf RF feature importances
df_feat_importances["combined_importance"] = \
    df_feat_importances["lGBM_importance_normalized"] \
    + df_feat_importances["RF_importance_normalized"]

df_feat_importances.sort_values(by="combined_importance",
                                ascending=False).head(15)
# Out:
#                         feature  lGBM_importance  lGBM_importance_normalized  fi_lGBM_ranking  RF_importance  RF_importance_normalized  fi_RF_ranking  combined_importance
# 5               EXT_SOURCE_MEAN           3611.0                      0.8965                5         0.0440                    1.0000              0               1.8965
# 1                  EXT_SOURCE_2           3927.0                      0.9749                1         0.0293                    0.6649              1               1.6398
# 0             DAYS_REGISTRATION           4028.0                      1.0000                0         0.0075                    0.1709             19               1.1709
# 3          CREDIT_ANNUITY_RATIO           3846.0                      0.9548                3         0.0093                    0.2117              7               1.1665
# 2               DAYS_ID_PUBLISH           3891.0                      0.9660                2         0.0077                    0.1740             17               1.1400
# 20                 EXT_SOURCE_3           2646.0                      0.6569               20         0.0199                    0.4521              2               1.1090
# 4                    DAYS_BIRTH           3632.0                      0.9017                4         0.0087                    0.1980             10               1.0996
# 9              INCOME_EXT_RATIO           3088.0                      0.7666                9         0.0121                    0.2747              3               1.0414
# 7           CREDIT_INCOME_RATIO           3280.0                      0.8143                7         0.0076                    0.1736             18               0.9879
# 6           OBS_30_CREDIT_RATIO           3352.0                      0.8322                6         0.0068                    0.1545             22               0.9867
# 8        DAYS_LAST_PHONE_CHANGE           3129.0                      0.7768                8         0.0078                    0.1777             15               0.9545
# 11     DAYS_CREDIT_MEAN_OVERALL           2947.0                      0.7316               11         0.0093                    0.2117              8               0.9433
# 18           CAR_EMPLOYED_RATIO           2717.0                      0.6745               18         0.0105                    0.2398              5               0.9143
# 10   REGION_POPULATION_RELATIVE           3017.0                      0.7490               10         0.0061                    0.1377             36               0.8867
# 15  REGIONS_RATING_INCOME_MUL_0           2805.0                      0.6964               15         0.0079                    0.1793             14               0.8757

# %%
# Graphical representation of combined lGBM and RF normalized importances
plt.figure(figsize=(10, 5))
sns.histplot(df_feat_importances, x="combined_importance", bins=40, kde=True)
plt.title('Feature Importance - Combination lightGBM and Random Forest')
plt.show()
# Out:
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:13: E124 closing bracket does not match visual indentation

# %% [markdown]
# <a id='select_combined_normalized_importance_over_02'></a>
#
# ### <span style='background:#0075bc'><span style='color:white'>Features with a combined normalized importance under 0.2 will be removed</span></span>

# %%
df_feat_imp_selec = df_feat_importances.copy()
df_feat_imp_lGBM_selec = df_feat_importance_lGBM.copy()
df_feat_imp_RF_selec = df_feat_importance_RF.copy()

# %%
df_feat_importances.shape
# Out:
# (395, 8)

# %%
# Features with a combined normalized importance under 0.2 will be removed
to_remove02 = \
    df_feat_imp_selec.loc[df_feat_imp_selec["combined_importance"] <= 0.20]
print(f"Features to remove", to_remove02.shape[0])

# Feaatures with a combined normalized importance over 0.2 will be selected
to_select02 = \
    df_feat_imp_selec.loc[df_feat_imp_selec["combined_importance"] > 0.20]

to_select02.shape
print(f"Selected features", to_select02.shape[0])
# Out:
# 3:67: E225 missing whitespace around operator
# 8:67: E225 missing whitespace around operator
# Features to remove 235
# Selected features 160

# %%
# Prepare data for verification
to_remove02["Action"] = "Delete"
to_select02["Action"] = "Select"

features_action02 = [to_select02[["feature", "Action"]],
                     to_remove02[["feature", "Action"]]]
action_features02 = pd.concat(features_action02)

df_feat_imp_selec_02_lGBM = df_feat_imp_lGBM_selec.merge(action_features02,
                                                         on="feature")
df_feat_imp_selec_02_RF = df_feat_imp_RF_selec.merge(action_features02,
                                                     on="feature")
# Out:
# 6:20: E128 continuation line under-indented for visual indent
# 10:57: E128 continuation line under-indented for visual indent

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_selec_02_lGBM,
                 x="lGBM_importance_normalized", y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('LightGBM, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_selec_02_RF, x="RF_importance_normalized",
                 y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('Random Forest, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
train_data_fs_02 = train_data_std.copy()
test_data_fs_02 = test_data_std.copy()

# Remove features with a combined normalized importance under 0.2
train_data_fs_02 = \
        train_data_fs_02.drop(columns=to_remove02['feature'].tolist())
test_data_fs_02 = \
        test_data_fs_02.drop(columns=to_remove02['feature'].tolist())

print(f'train_data : {train_data_fs_02.shape}')
print(f'test_data : {test_data_fs_02.shape}')
# Out:
# train_data : (307511, 160)
# test_data : (48744, 160)

# %% [markdown]
# **Reconstruct datasets**

# %%
train_data_fs_02['TARGET'] = target_train
train_data_fs_02['SK_ID_CURR'] = skid_train
print(f'train_data : {train_data_fs_02.shape}')

test_data_fs_02['SK_ID_CURR'] = skid_test
print(f'test_data : {test_data_fs_02.shape}')
# Out:
# train_data : (307511, 162)
# test_data : (48744, 161)

# %% [markdown]
# **Saving datasets after feature selection**

# %%
# Saving datasets after feature selection ready for ML
path_train_data_feat_select = \
    '../P7_scoring_credit/preprocessing/train_data_fs_02_ML.pkl'
with open(path_train_data_feat_select, 'wb') as f:
    pickle.dump(train_data_fs_02, f, pickle.HIGHEST_PROTOCOL)

# %%
# Saving datasets after feature selection ready for ML
path_test_data_feat_select = \
    '../P7_scoring_credit/preprocessing/test_data_fs_02_ML.pkl'
with open(path_test_data_feat_select, 'wb') as f:
    pickle.dump(test_data_fs_02, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# <a id='select_combined_normalized_importance_over_05'></a>
#
# ### <span style='background:#0075bc'><span style='color:white'>Features with a combined normalized importance under 0.5 will be removed</span></span>

# %%
df_feat_imp_selec = df_feat_importances.copy()
df_feat_imp_lGBM_selec = df_feat_importance_lGBM.copy()
df_feat_imp_RF_selec = df_feat_importance_RF.copy()

# %%
# Features with a combined normalized importance under 0.5 will be removed
to_remove05 = \
    df_feat_imp_selec.loc[df_feat_imp_selec["combined_importance"] <= 0.50]
print(f"Features to remove", to_remove05.shape[0])

# Feaatures with a combined normalized importance over 0.7 will be selected
to_select05 = \
    df_feat_imp_selec.loc[df_feat_imp_selec["combined_importance"] > 0.50]
to_select05.shape
print(f"Selected features", to_select05.shape[0])
# Out:
# 3:67: E225 missing whitespace around operator
# 8:67: E225 missing whitespace around operator
# Features to remove 315
# Selected features 80

# %%
# Prepare data for verification
to_remove05["Action"] = "Delete"
to_select05["Action"] = "Select"

features_action05 = [to_select05[["feature", "Action"]],
                     to_remove05[["feature", "Action"]]]
action_features05 = pd.concat(features_action05)

df_feat_imp_lGBM_selec05 = df_feat_imp_lGBM_selec.merge(action_features05,
                                                        on="feature")
df_feat_imp_selec05_RF = df_feat_imp_RF_selec.merge(action_features05,
                                                    on="feature")

# %%
#Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_lGBM_selec05,
                 x="lGBM_importance_normalized", y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('LightGBM, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_selec05_RF, x="RF_importance_normalized",
                 y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('Random Forest, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
train_data_fs_05 = train_data_std.copy()
test_data_fs_05 = test_data_std.copy()

# Remove features with a combined normalized importance under 0.5
train_data_fs_05 = \
        train_data_fs_05.drop(columns=to_remove05['feature'].tolist())
test_data_fs_05 = \
        test_data_fs_05.drop(columns=to_remove05['feature'].tolist())

print(f'train_data : {train_data_fs_05.shape}')
print(f'test_data : {test_data_fs_05.shape}')
# Out:
# 4:80: E501 line too long (81 > 79 characters)
# train_data : (307511, 80)
# test_data : (48744, 80)

# %% [markdown]
# **Reconstruct datasets**

# %%
train_data_fs_05['TARGET'] = target_train
train_data_fs_05['SK_ID_CURR'] = skid_train
print(f'train_data : {train_data_fs_05.shape}')

test_data_fs_05['SK_ID_CURR'] = skid_test
print(f'test_data : {test_data_fs_05.shape}')
# Out:
# train_data : (307511, 82)
# test_data : (48744, 81)

# %% [markdown]
# **Saving datasets after feature selection**

# %%
# Saving datasets after feature selection ready for ML
path_train_data_feat_select = \
    '../P7_scoring_credit/preprocessing/train_data_fs_05_ML.pkl'
with open(path_train_data_feat_select, 'wb') as f:
    pickle.dump(train_data_fs_05, f, pickle.HIGHEST_PROTOCOL)

# %%
# Saving datasets after feature selection ready for ML
path_test_data_feat_select = \
    '../P7_scoring_credit/preprocessing/test_data_fs_05_ML.pkl'
with open(path_test_data_feat_select, 'wb') as f:
    pickle.dump(test_data_fs_05, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# <a id='select_combined_normalized_importance_15highest'></a>
#
# ### <span style='background:#0075bc'><span style='color:white'>15 highest values of combined normalized importance will be selected</span></span>

# %%
df_feat_imp_selec = df_feat_importances.copy()
df_feat_importance_lGBM_selec = df_feat_importance_lGBM.copy()
df_feat_importance_RF_selec = df_feat_importance_RF.copy()

# %%
# 15 highest values of combined normalized importance will be selected
to_select_15 = df_feat_imp_selec.sort_values(by="combined_importance",
                                             ascending=False).head(15)
to_select_15.shape
print(f"Selected features", to_select_15.shape[0])
# Out:
# Selected features 15

# %%
# Features to remove
to_remove_15 = df_feat_imp_selec.loc[~df_feat_imp_selec.index.isin(
                                        to_select_15.index.tolist())]
print(f"Features to remove", to_remove_15.shape[0])
# Out:
# Features to remove 380

# %%
# Prepare data for verification
to_remove_15["Action"] = "Delete"
to_select_15["Action"] = "Select"

features_action_15 = [to_select_15[["feature", "Action"]],
                      to_remove_15[["feature", "Action"]]]
action_features_15 = pd.concat(features_action_15)

df_feat_imp_lGBM_15 = df_feat_imp_lGBM_selec.merge(action_features_15,
                                                   on="feature")
df_feat_imp_RF_15 = df_feat_imp_RF_selec.merge(action_features_15,
                                               on="feature")

# %%
#Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_lGBM_15,
                 x="lGBM_importance_normalized", y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('LightGBM, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_RF_15, x="RF_importance_normalized",
                 y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('Random Forest, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
train_data_fs_15 = train_data_std.copy()
test_data_fs_15 = test_data_std.copy()

# Remove features not selected
train_data_fs_15 = \
        train_data_fs_15.drop(columns=to_remove_15['feature'].tolist())
test_data_fs_15 = \
        test_data_fs_15.drop(columns=to_remove_15['feature'].tolist())

print(f'train_data : {train_data_fs_15.shape}')
print(f'test_data : {test_data_fs_15.shape}')
# Out:
# train_data : (307511, 15)
# test_data : (48744, 15)

# %% [markdown]
# **Reconstruct datasets**

# %%
train_data_fs_15['TARGET'] = target_train
train_data_fs_15['SK_ID_CURR'] = skid_train
print(f'train_data : {train_data_fs_15.shape}')

test_data_fs_15['SK_ID_CURR'] = skid_test
print(f'test_data : {test_data_fs_15.shape}')
# Out:
# train_data : (307511, 17)
# test_data : (48744, 16)

# %% [markdown]
# **Saving datasets after feature selection**

# %%
# Saving datasets after feature selection ready for ML
path_train_data_feat_select = \
    '../P7_scoring_credit/preprocessing/train_data_fs_15_ML.pkl'
with open(path_train_data_feat_select, 'wb') as f:
    pickle.dump(train_data_fs_15, f, pickle.HIGHEST_PROTOCOL)

# %%
# Saving datasets after feature selection ready for ML
path_test_data_feat_select = \
    '../P7_scoring_credit/preprocessing/test_data_fs_15_ML.pkl'
with open(path_test_data_feat_select, 'wb') as f:
    pickle.dump(test_data_fs_15, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# <a id='select_combined_10best_lgbm_rf'></a>
#
# ### <span style='background:#0075bc'><span style='color:white'>10 best values of normalized importance from LightGBM and RandomForest will be selected</span></span>

# %%
df_feat_imp_selec = df_feat_importances.copy()
df_feat_imp_lGBM_selec = df_feat_importance_lGBM.copy()
df_feat_imp_RF_selec = df_feat_importance_RF.copy()

# %%
# 10 highest values of normalized importance will be selected
top_10_lgbm = df_feat_imp_selec.sort_values(by="lGBM_importance_normalized",
                                            ascending=False).head(10)
top_10_rf = df_feat_imp_selec.sort_values(by="RF_importance_normalized",
                                          ascending=False).head(10)

# %%
# Lists with the 10 best values for each method
top_10_lgbm_feat = top_10_lgbm["feature"].tolist()
top_10_rf_feat = top_10_rf["feature"].tolist()

# Combine both lists
top_10_rf_but_not_lgbm = set(top_10_rf_feat) - set(top_10_lgbm_feat)
list_top_combined = top_10_lgbm_feat + list(top_10_rf_but_not_lgbm)
print(f'The combination of 10 best results from each method results \
      in the selection of {len(list_top_combined)} features')

top10_combined = df_feat_imp_selec.loc[df_feat_imp_selec["feature"].isin(
                                                        list_top_combined)]
# Out:
#   Cell In[163], line 8
#     print(f'The combination of 10 best results from each method results
#           ^
# SyntaxError: unterminated string literal (detected at line 8)
# Error before execution: unterminated string literal (detected at line 8) (3992497142.py, line 8)

# %%
# Features to remove
to_remove_combined_top10 = \
        df_feat_imp_selec.loc[~df_feat_imp_selec.index.isin(
                                            top10_combined.index.tolist())]
print(f"Features to remove", to_remove_combined_top10.shape[0])
# Out:
# Features to remove 379

# %%
# Prepare data for verification
to_remove_combined_top10["Action"] = "Delete"
top10_combined["Action"] = "Select"

features_action_combined_top10 = [top10_combined[["feature", "Action"]],
                                  to_remove_combined_top10[["feature",
                                                            "Action"]]]
action_features_combined_top10 = pd.concat(features_action_combined_top10)

df_feat_imp_lGBM_comb_t10 = \
        df_feat_imp_lGBM_selec.merge(action_features_combined_top10,
                                     on="feature")
df_feat_imp_RF_comb_t10 = \
        df_feat_imp_RF_selec.merge(action_features_combined_top10,
                                   on="feature")

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_lGBM_comb_t10,
                 x="lGBM_importance_normalized", y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('LightGBM, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_RF_comb_t10, x="RF_importance_normalized",
                 y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('Random Forest, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
train_data_fs_top10 = train_data_std.copy()
test_data_fs_top10 = test_data_std.copy()

# Remove features not selected
train_data_fs_top10 = train_data_fs_top10.drop(
                         columns=to_remove_combined_top10['feature'].tolist())

test_data_fs_top10 = test_data_fs_top10.drop(
                      columns=to_remove_combined_top10['feature'].tolist())

print(f'train_data : {train_data_fs_top10.shape}')
print(f'test_data : {test_data_fs_top10.shape}')
# Out:
# 5:48: E502 the backslash is redundant between brackets
# 8:46: E502 the backslash is redundant between brackets
# train_data : (307511, 16)
# test_data : (48744, 16)

# %% [markdown]
# **Reconstruct datasets**

# %%
train_data_fs_top10['TARGET'] = target_train
train_data_fs_top10['SK_ID_CURR'] = skid_train
print(f'train_data : {train_data_fs_top10.shape}')

test_data_fs_top10['SK_ID_CURR'] = skid_test
print(f'test_data : {test_data_fs_top10.shape}')
# Out:
# train_data : (307511, 18)
# test_data : (48744, 17)

# %% [markdown]
# **Saving datasets after feature selection**

# %%
# Saving datasets after feature selection ready for ML
path_train_data_feat_select = \
    '../P7_scoring_credit/preprocessing/train_data_fs_top10_ML.pkl'
with open(path_train_data_feat_select, 'wb') as f:
    pickle.dump(train_data_fs_top10, f, pickle.HIGHEST_PROTOCOL)

# %%
# Saving datasets after feature selection ready for ML
path_test_data_feat_select = \
    '../P7_scoring_credit/preprocessing/test_data_fs_top10_ML.pkl'
with open(path_test_data_feat_select, 'wb') as f:
    pickle.dump(test_data_fs_top10, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# <a id='select_combined_25best_lgbm_rf'></a>
#
# ### <span style='background:#0075bc'><span style='color:white'>25 best values of normalized importance from LightGBM and RandomForest will be selected</span></span>

# %%
df_feat_imp_selec = df_feat_importances.copy()
df_feat_imp_lGBM_selec = df_feat_importance_lGBM.copy()
df_feat_imp_RF_selec = df_feat_importance_RF.copy()

# %%
# 25 highest values of normalized importance will be selected
top_25_lgbm = df_feat_imp_selec.sort_values(by="lGBM_importance_normalized",
                                            ascending=False).head(25)
top_25_rf = df_feat_imp_selec.sort_values(by="RF_importance_normalized",
                                          ascending=False).head(25)

# %%
# Lists with the 25 best values for each method
top_25_lgbm_feat = top_25_lgbm["feature"].tolist()
top_25_rf_feat = top_25_rf["feature"].tolist()

# Combine both lists
top_25_rf_but_not_lgbm = set(top_25_rf_feat) - set(top_25_lgbm_feat)
list_top25_combined = top_25_lgbm_feat + list(top_25_rf_but_not_lgbm)
print(f'The combination of 25 best results from each method results in \
    the selection of {len(list_top25_combined)} features')

top25_combined = df_feat_imp_selec.loc[df_feat_imp_selec["feature"]
                                       .isin(list_top25_combined)]
# Out:
# 11:68: E502 the backslash is redundant between brackets
# The combination of 25 best results from each method results in     the selection of 34 features

# %%
# Features to remove
to_remove_combined_t25 = df_feat_imp_selec.loc[~df_feat_imp_selec.index
                                        .isin(top25_combined.index.tolist())]
print(f"Features to remove", to_remove_combined_t25.shape[0])
# Out:
# 2:72: E502 the backslash is redundant between brackets
# 3:41: E128 continuation line under-indented for visual indent
# Features to remove 361

# %%
# Prepare data for verification
to_remove_combined_t25["Action"] = "Delete"
top25_combined["Action"] = "Select"

features_action_combined_t25 = [top25_combined[["feature", "Action"]],
                                to_remove_combined_t25[["feature",
                                                        "Action"]]]
action_features_combined_t25 = pd.concat(features_action_combined_t25)

df_feat_imp_lGBM_comb_t25 = \
            df_feat_imp_lGBM_selec.merge(action_features_combined_t25,
                                         on="feature")
df_feat_imp_RF_comb_t25 = \
            df_feat_imp_RF_selec.merge(action_features_combined_t25,
                                       on="feature")

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_lGBM_comb_t25,
                 x="lGBM_importance_normalized", y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('LightGBM, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
# Graphic representation of selected features
plt.figure(figsize=(5, 6))

ax = sns.barplot(data=df_feat_imp_RF_comb_t25, x="RF_importance_normalized",
                 y="feature", hue="Action")
ax.set_ylabel(None)
ax.set_yticks([])

plt.xlabel('Importance normalisée')
plt.title('Random Forest, Features Importances')
plt.show()
# Out:
# 1:1: E265 block comment should start with '# '
# 2:19: E251 unexpected spaces around keyword / parameter equals
# 2:21: E251 unexpected spaces around keyword / parameter equals
# 4:3: E225 missing whitespace around operator

# %%
train_data_fs_t25 = train_data_std.copy()
test_data_fs_t25 = test_data_std.copy()

# Remove features not selected
train_data_fs_t25 = train_data_fs_t25.drop(
                        columns=to_remove_combined_t25['feature'].tolist())
test_data_fs_t25 = test_data_fs_t25.drop(
                        columns=to_remove_combined_t25['feature'].tolist())

print(f'train_data : {train_data_fs_t25.shape}')
print(f'test_data : {test_data_fs_t25.shape}')
# Out:
# 5:44: E502 the backslash is redundant between brackets
# 7:42: E502 the backslash is redundant between brackets
# train_data : (307511, 34)
# test_data : (48744, 34)

# %% [markdown]
# **Reconstruct datasets**

# %%
train_data_fs_t25['TARGET'] = target_train
train_data_fs_t25['SK_ID_CURR'] = skid_train
print(f'train_data : {train_data_fs_t25.shape}')

test_data_fs_t25['SK_ID_CURR'] = skid_test
print(f'test_data : {test_data_fs_t25.shape}')
# Out:
# train_data : (307511, 36)
# test_data : (48744, 35)

# %% [markdown]
# **Saving datasets after feature selection**

# %%
# Saving datasets after feature selection ready for ML
path_train_data_feat_select = \
    '../P7_scoring_credit/preprocessing/train_data_fs_t25_combi_ML.pkl'
with open(path_train_data_feat_select, 'wb') as f:
    pickle.dump(train_data_fs_t25, f, pickle.HIGHEST_PROTOCOL)

# %%
# Saving datasets after feature selection ready for ML
path_test_data_feat_select = \
    '../P7_scoring_credit/preprocessing/test_data_fs_t25_combi_ML.pkl'
with open(path_test_data_feat_select, 'wb') as f:
    pickle.dump(test_data_fs_t25, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# <a id='feat_select_summary'></a>
#
# ## <span style='background:#0085dd'><span style='color:white'>Summary</span></span>

# %% [markdown]
# Several variable selection strategies have been tested.<br>
# The feature importances generated by linear and non-linear algorithms are different. In order to integrate the use of the variables obtained by both algorithm families, the importances have been normalised.<br>
# The strategy offering the best results (compromise between computation time and performance preservation) consists in considering the 25 most important feature importances for LightGBM and the 25 most important for Random Forest. In total 34 variables are retained for modelling.
